# %% [markdown]
# <a href="https://colab.research.google.com/github/DevaHarshiniModepalli/DevaHarshini425/blob/main/ASSIGNMENT_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Day_7_sales_data.csv')
df
# Out:
#           Date     Product Region    Sales  Profit  Quantity
# 0   2023-01-02      Tablet   East  1061.81  236.12         7
# 1   2023-01-06      Laptop  North  1926.07  246.34         8
# 2   2023-01-03      Tablet   East  1597.99  253.17         3
# 3   2023-01-20      Tablet  North  1397.99  242.23         1
# 4   2023-01-04      Laptop   West   734.03  140.36         4
# 5   2023-01-17      Tablet  North   733.99  188.66         2
# 6   2023-01-14    Keyboard   East   587.13   82.16         8
# 7   2023-01-07  Smartphone   East  1799.26  364.97         4
# 8   2023-01-11  Smartphone   West  1401.67  306.24         2
# 9   2023-01-01      Laptop  North  1562.11  170.72         6
# 10  2023-01-19     Monitor  North   530.88  117.59         6
# 11  2023-01-12      Laptop   West  1954.86  262.16         4
# 12  2023-01-09     Monitor  North  1748.66  197.62         6
# 13  2023-01-10  Smartphone  North   818.51  237.19         2
# ...

# %%
df.head(5)
# Out:
#          Date Product Region    Sales  Profit  Quantity
# 0  2023-01-02  Tablet   East  1061.81  236.12         7
# 1  2023-01-06  Laptop  North  1926.07  246.34         8
# 2  2023-01-03  Tablet   East  1597.99  253.17         3
# 3  2023-01-20  Tablet  North  1397.99  242.23         1
# 4  2023-01-04  Laptop   West   734.03  140.36         4

# %%
df.describe()
# Out:
#              Sales      Profit   Quantity
# count    20.000000   20.000000  20.000000
# mean   1186.553000  211.533000   5.050000
# std     461.528444   66.916251   2.543826
# min     530.880000   82.160000   1.000000
# 25%     774.517500  166.515000   2.750000
# 50%    1104.865000  214.670000   5.000000
# 75%    1571.080000  248.047500   7.250000
# max    1954.860000  364.970000   9.000000

# %%
df['Sales'].sum()
# Out:
# 23731.06

# %%
df['Region'].unique()
# Out:
# array(['East', 'North', 'West', 'South'], dtype=object)

# %%
# result=
df.groupby('Region')['Sales'].sum()
# print(result)
# Out:
# Region
# East      5818.93
# North    10449.68
# South      936.84
# West      6525.61
# Name: Sales, dtype: float64

# %%
# a=df['Quantity'].describe()
# a[7]
# Out:
# 9.0

# %%
df.groupby('Product')['Quantity'].sum().idxmax()
# Out:
# 'Tablet'

# %% [markdown]
# to find the max sold product based on quantity

# %%
a=df.groupby('Product')['Profit'].max()
a
#  [df['Profit'] / df['Sales'] * 100]
# Out:
# Product
# Keyboard      202.83
# Laptop        262.16
# Monitor       197.62
# Smartphone    364.97
# Tablet        271.88
# Name: Profit, dtype: float64

# %%
# grouped_data = df.groupby('Product')

# %%
# sales_per_product = grouped_data['Sales'].sum()
# print(sales_per_product)
# Out:
# Product
# Keyboard      1362.24
# Laptop        6949.81
# Monitor       3566.67
# Smartphone    4019.44
# Tablet        7832.90
# Name: Sales, dtype: float64

# %%
# avg_quantity_per_product = grouped_data['Quantity'].mean()
# print(avg_quantity_per_product)
# Out:
# Product
# Keyboard      6.000000
# Laptop        4.800000
# Monitor       6.333333
# Smartphone    2.666667
# Tablet        5.428571
# Name: Quantity, dtype: float64

# %%
# max_profit_per_product = grouped_data['Profit'].max()
# print(max_profit_per_product)
# Out:
# Product
# Keyboard      202.83
# Laptop        262.16
# Monitor       197.62
# Smartphone    364.97
# Tablet        271.88
# Name: Profit, dtype: float64

# %%
a
# Out:
# Product
# Keyboard      202.83
# Laptop        262.16
# Monitor       197.62
# Smartphone    364.97
# Tablet        271.88
# Name: Profit, dtype: float64
